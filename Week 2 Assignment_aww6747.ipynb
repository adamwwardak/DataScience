# %% [markdown]
# Adam Wardak - aww6747
#
# Data Science Bootcamp
#
# Instructor Rohan Chopra
#
# Week 2 Assignment

# %% [markdown]
# Part 1 - Numpy
#
# Use this dataset for the first 4 questions.
#
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
#
# iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])
#
# 1.⁠ ⁠Define two custom numpy arrays, say A and B. Generate two new numpy arrays by stacking A and B vertically and horizontally.

# %%
import numpy as np

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# %%
A = iris_2d[:, 0]
B = iris_2d[:, 1]
V = np.vstack((A,B))
H = np.hstack((A,B))

print("This is arrays A and B vertically stacked:")
print(V)
print("This is arrays A and B horizontally stacked:")
print(H)
# Out:
# This is arrays A and B vertically stacked:
# [[5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#   5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#   5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#   6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#   6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#   5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#   6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#   6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#   6.7 6.7 6.3 6.5 6.2 5.9]
#  [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#   3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#   3.5 3.1 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#   2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
# ...

# %% [markdown]
# 2.⁠ ⁠Find common elements between A and B. [Hint : Intersection of two sets]

# %%
intersection = np.intersect1d(A, B)
print(intersection)
# Out:
# [4.4]

# %% [markdown]
# 3.⁠ ⁠Extract all numbers from A which are within a specific range. eg between 5 and 10. [Hint: np.where() might be useful or boolean masks]

# %%
Extract = A[np.where((A > 5) & (A < 10))]
Extract
# Out:
# array([5.1, 5.4, 5.4, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 5.1, 5.2,
#        5.2, 5.4, 5.2, 5.5, 5.5, 5.1, 5.1, 5.1, 5.3, 7. , 6.4, 6.9, 5.5,
#        6.5, 5.7, 6.3, 6.6, 5.2, 5.9, 6. , 6.1, 5.6, 6.7, 5.6, 5.8, 6.2,
#        5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6. , 5.7, 5.5, 5.5,
#        5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.6, 5.7,
#        5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 7.3, 6.7, 7.2,
#        6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6. , 6.9, 5.6, 7.7,
#        6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7,
#        6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2,
#        5.9])

# %% [markdown]
# 4.⁠ ⁠Filter the rows of iris_2d that has petallength (3rd column) > 1.5 and sepallength (1st column) < 5.0

# %%
Filtered = iris_2d[np.where((iris_2d[:, 2] > 1.5) & (iris_2d[:, 0] < 5.0))]
Filtered
# Out:
# array([[4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [4.9, 2.4, 3.3, 1. ],
#        [4.9, 2.5, 4.5, 1.7]])

# %% [markdown]
# Part 2 - Pandas
#
# 1.⁠ ⁠From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).
#
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
Filtered_df = df[['Manufacturer', 'Model', 'Type']].iloc[::20]
Filtered_df
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# 2.⁠ ⁠Replace missing values in Min.Price and Max.Price columns with their respective mean.
#
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
#inspecting the data to see missing values
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
# 92          NaN      850  Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %%
df[['Min.Price', 'Max.Price']] = df[['Min.Price', 'Max.Price']].replace("NA", np.nan).apply(lambda col: col.fillna(col.median()))
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9      18.80      25.0
# 1           NaN   Legend  Midsize       29.2   33.9      38.70      18.0
# 2          Audi       90  Compact       25.9   29.1      32.30      20.0
# 3          Audi      100  Midsize       14.6   37.7      44.60      19.0
# 4           BMW     535i  Midsize       14.6   30.0      19.15      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7      22.70      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0      22.40      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3      23.70      18.0
# 91        Volvo      240  Compact       21.8   22.7      23.50      21.0
# 92          NaN      850  Midsize       24.8   26.7      28.50      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# ...

# %% [markdown]
# 3.⁠ ⁠How to get the rows of a dataframe with row sum > 100?
#
# df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df_greaterthan100 = df[df[[0, 1, 2, 3]].sum(axis=1) > 100]
df_greaterthan100
# Out:
#      0   1   2   3
# 1   38  24  24  27
# 10  28  22  37  22
# 11  38  17  32  16
# 14  24  32  17  30
